# %%
import pandas as pd
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook(hide_banner=True)
from bokeh.models import Span

# %%
# Energy
# O_XAS XANES XES

# %%
up00xes = pd.read_csv('./CoFeMn/CoFeMn_000U_up_O_XES.csv')
up00xas = pd.read_csv('./CoFeMn/CoFeMn_000U_up_O_XAS.csv')
up30xes = pd.read_csv('./CoFeMn/CoFeMn_030U_up_O_XES.csv')
up30xas = pd.read_csv('./CoFeMn/CoFeMn_030U_up_O_XAS.csv')
up52xes = pd.read_csv('./CoFeMn/CoFeMn_052U_up_O_XES.csv')
up52xas = pd.read_csv('./CoFeMn/CoFeMn_052U_up_O_XAS.csv')
up60xes = pd.read_csv('./CoFeMn/CoFeMn_060U_up_O_XES.csv')
up60xas = pd.read_csv('./CoFeMn/CoFeMn_060U_up_O_XAS.csv')
up70xes = pd.read_csv('./CoFeMn/CoFeMn_070U_up_O_XES.csv')
up70xas = pd.read_csv('./CoFeMn/CoFeMn_070U_up_O_XAS.csv')
p = figure(title='Comparison Of Plus U Parameters', x_axis_label='Energy', y_axis_label='Counts')
offset = 0.045
p.line(up00xes['Energy'],up00xes['O_XES'],line_color="brown",legend_label="0.00U_RKM7_300k_SP") # Are these params right???
p.line(up30xes['Energy'],up30xes['O_XES']+offset,line_color="blue",legend_label="0.30U_RKM6.23_600k")
#p.line(up30xas['Energy'],up30xas['O_XAS'],line_color="blue")
p.line(up52xes['Energy'],up52xes['O_XES']+offset*2,line_color="black",legend_label="0.52U_RKM6.23_600k")
#p.line(up52xas['Energy'],up52xas['O_XAS']+offset,line_color="black")
p.line(up60xes['Energy'],up60xes['O_XES']+offset*3,line_color="red",legend_label="0.60U_RKM7_300k_P4")
#p.line(up60xas['Energy'],up60xas['O_XAS']+offset*2,line_color="red")
p.line(up70xes['Energy'],up70xes['O_XES']+offset*4,line_color="magenta",legend_label="0.70U_RKM7_300k_P4")
p.legend.location = "left"
show(p)
# Out:
#   <div class="bk-root" id="c3ff9413-4bab-4fcc-8089-52888414ddc6" data-root-id="1002"></div>

# %%
dn00xes = pd.read_csv('./CoFeMn/CoFeMn_000U_dn_O_XES.csv')
dn00xas = pd.read_csv('./CoFeMn/CoFeMn_000U_dn_O_XAS.csv')
dn30xes = pd.read_csv('./CoFeMn/CoFeMn_030U_dn_O_XES.csv')
dn30xas = pd.read_csv('./CoFeMn/CoFeMn_030U_dn_O_XAS.csv')
dn52xes = pd.read_csv('./CoFeMn/CoFeMn_052U_dn_O_XES.csv')
dn52xas = pd.read_csv('./CoFeMn/CoFeMn_052U_dn_O_XAS.csv')
dn60xes = pd.read_csv('./CoFeMn/CoFeMn_060U_dn_O_XES.csv')
dn60xas = pd.read_csv('./CoFeMn/CoFeMn_060U_dn_O_XAS.csv')
dn70xes = pd.read_csv('./CoFeMn/CoFeMn_070U_dn_O_XES.csv')
dn70xas = pd.read_csv('./CoFeMn/CoFeMn_070U_dn_O_XAS.csv')

p = figure(title='CoFeMn Plus U Spin Down', x_axis_label='Energy', y_axis_label='Counts')
offset = 0.045
p.line(dn00xes['Energy'],dn00xes['O_XES'],line_color="brown",legend_label="0.00U_RKM7_300k_SP")
p.line(dn00xas['Energy'],dn00xas['O_XAS'],line_color="brown")
p.line(dn30xes['Energy'],dn30xes['O_XES']+offset,line_color="blue",legend_label="0.30U_RKM6.23_600k")
p.line(dn30xas['Energy'],dn30xas['O_XAS']+offset,line_color="blue")
p.line(dn52xes['Energy'],dn52xes['O_XES']+offset*2,line_color="black",legend_label="0.52U_RKM6.23_600k")
p.line(dn52xas['Energy'],dn52xas['O_XAS']+offset*2,line_color="black")
p.line(dn60xes['Energy'],dn60xes['O_XES']+offset*3,line_color="red",legend_label="0.60U_RKM7_300k_P4")
p.line(dn60xas['Energy'],dn60xas['O_XAS']+offset*3,line_color="red")
p.line(dn70xes['Energy'],dn70xes['O_XES']+offset*4,line_color="magenta",legend_label="0.70U_RKM7_300k_P4")
p.line(dn70xas['Energy'],dn70xas['O_XAS']+offset*4,line_color="magenta")
p.legend.location = "left"
show(p)
# Out:
#   <div class="bk-root" id="b47d7c2e-d525-4c8c-83da-b3242e2a1492" data-root-id="1249"></div>

# %%
# Energy
# O_XAS XANES XES

# %%
# SPIN DOWN
# Same data as above, but organized slightly differently

up_or_dn = "dn"

# CoFeMnSP
# 000U, RKM7, 300k
xes00 = pd.read_csv('./CoFeMn/CoFeMn_000U_'+up_or_dn+'_O_XES.csv')
xas00 = pd.read_csv('./CoFeMn/CoFeMn_000U_'+up_or_dn+'_O_XAS.csv')


# CoFeMnPlusU
# 030U, RKM6.23, 600k
xes30 = pd.read_csv('./CoFeMn/CoFeMn_030U_'+up_or_dn+'_O_XES.csv')
xas30 = pd.read_csv('./CoFeMn/CoFeMn_030U_'+up_or_dn+'_O_XAS.csv')

# 052U, RKM6.23, 600k
xes52 = pd.read_csv('./CoFeMn/CoFeMn_052U_'+up_or_dn+'_O_XES.csv')
xas52 = pd.read_csv('./CoFeMn/CoFeMn_052U_'+up_or_dn+'_O_XAS.csv')

# 060U, RKM6.23, 600k
xes60PU = pd.read_csv('./CoFeMn/CoFeMn_060U_PU_'+up_or_dn+'_O_XES.csv')
xas60PU = pd.read_csv('./CoFeMn/CoFeMn_060U_PU_'+up_or_dn+'_O_XAS.csv')


# CoFeMnPlusU4
# 050U, RKM7, 300k
xes50 = pd.read_csv('./CoFeMn/CoFeMn_050U_'+up_or_dn+'_O_XES.csv')
xas50 = pd.read_csv('./CoFeMn/CoFeMn_050U_'+up_or_dn+'_O_XAS.csv')

# 050U, RKM7, 600k
# Only 3 cycles before it converged again, so idk.
xes50P4 = pd.read_csv('./CoFeMn/CoFeMn_050U_600k_'+up_or_dn+'_O_XES.csv')
xas50P4 = pd.read_csv('./CoFeMn/CoFeMn_050U_600k_'+up_or_dn+'_O_XAS.csv')

# 060U, RKM7, 300k
xes60 = pd.read_csv('./CoFeMn/CoFeMn_060U_'+up_or_dn+'_O_XES.csv')
xas60 = pd.read_csv('./CoFeMn/CoFeMn_060U_'+up_or_dn+'_O_XAS.csv')

# 070U, RKM7, 300k
xes70 = pd.read_csv('./CoFeMn/CoFeMn_070U_'+up_or_dn+'_O_XES.csv')
xas70 = pd.read_csv('./CoFeMn/CoFeMn_070U_'+up_or_dn+'_O_XAS.csv')


# CoFeMnPlusU3
# 070U, RKM7, 600k
xes70P3 = pd.read_csv('./CoFeMn/CoFeMn_070U_600k_'+up_or_dn+'_O_XES.csv')
xas70P3 = pd.read_csv('./CoFeMn/CoFeMn_070U_600k_'+up_or_dn+'_O_XAS.csv')

# %%
p = figure(title='CoFeMn Plus U Calculations', x_axis_label='Energy', y_axis_label='Counts',x_range=(475, 575))
yoffset = 0.05
xoffset = 20

# CoFeMnSP
XES=xes00
XAS=xas00
p.line(XES['Energy']+xoffset*0,XES['O_XES']+yoffset*0,line_color="red",legend_label="0.00U_RKM7_300k_SP")
#p.line(XAS['Energy']+xoffset*0,XAS['O_XAS']+yoffset*0,line_color="red")

# CoFeMnPlusU
XES=xes30
XAS=xas30
p.line(XES['Energy']+xoffset*1,XES['O_XES']+yoffset*0,line_color="red",legend_label="0.30U_RKM6.23_600k_PU")
#p.line(XAS['Energy']+xoffset*1,XAS['O_XAS']+yoffset*0,line_color="red")

XES=xes52
XAS=xas52
p.line(XES['Energy']+xoffset*1,XES['O_XES']+yoffset*1,line_color="blue",legend_label="0.52U_RKM6.23_600k_PU")
#p.line(XAS['Energy']+xoffset*1,XAS['O_XAS']+yoffset*1,line_color="blue")

XES=xes60PU
XAS=xas60PU
p.line(XES['Energy']+xoffset*1,XES['O_XES']+yoffset*2,line_color="magenta",legend_label="0.60U_RKM6.23_600k_PU")
#p.line(XAS['Energy']+xoffset*1,XAS['O_XAS']+yoffset*2,line_color="magenta")


# CoFeMnPlusU4
XES=xes50
XAS=xas50
p.line(XES['Energy']+xoffset*2,XES['O_XES']+yoffset*0,line_color="red",legend_label="0.50U_RKM7_300k_P4")
#p.line(XAS['Energy']+xoffset*2,XAS['O_XAS']+yoffset*0,line_color="red")

XES=xes50P4
XAS=xas50P4
p.line(XES['Energy']+xoffset*2,XES['O_XES']+yoffset*1,line_color="blue",legend_label="0.50U_RKM7_600k_P4")
#p.line(XAS['Energy']+xoffset*2,XAS['O_XAS']+yoffset*1,line_color="blue")

XES=xes60
XAS=xas60
p.line(XES['Energy']+xoffset*2,XES['O_XES']+yoffset*2,line_color="magenta",legend_label="0.60U_RKM7_300k_P4")
#p.line(XAS['Energy']+xoffset*2,XAS['O_XAS']+yoffset*2,line_color="magenta")

XES=xes70
XAS=xas70
p.line(XES['Energy']+xoffset*2,XES['O_XES']+yoffset*3,line_color="brown",legend_label="0.70U_RKM7_300k_P4")
#p.line(XAS['Energy']+xoffset*2,XAS['O_XAS']+yoffset*3,line_color="brown")

# CoFeMnPlusU3
XES=xes70P3
XAS=xas70P3
p.line(XES['Energy']+xoffset*3,XES['O_XES']+yoffset*0,line_color="red",legend_label="0.70U_RKM7_300k_P3")
#p.line(XAS['Energy']+xoffset*3,XAS['O_XAS']+yoffset*0,line_color="red")

p.legend.location = "top_left"
show(p)
# Out:
#   <div class="bk-root" id="f311f83a-5573-47a5-af13-e26690c9203d" data-root-id="3085"></div>

# %%
p = figure(title='CoFeMn Plus U Calculations', x_axis_label='Energy', y_axis_label='Counts',x_range=(470, 530))
yoffset = 0.05
xoffset = 20


XES=xes00
p.line(XES['Energy']+xoffset*0,XES['O_XES']+yoffset*0,line_color="red",legend_label="0.00U_RKM7_300k_SP")

XES=xes30
p.line(XES['Energy']+xoffset*0,XES['O_XES']+yoffset*1,line_color="blue",legend_label="0.30U_RKM6.23_600k_PU")

XES=xes50
p.line(XES['Energy']+xoffset*0,XES['O_XES']+yoffset*2,line_color="magenta",legend_label="0.50U_RKM7_300k_P4")

XES=xes50P4
p.line(XES['Energy']+xoffset*1,XES['O_XES']+yoffset*2,line_color="black",legend_label="0.50U_RKM7_600k_P4")

XES=xes52
p.line(XES['Energy']+xoffset*0,XES['O_XES']+yoffset*3,line_color="brown",legend_label="0.52U_RKM6.23_600k_PU")

XES=xes60PU
p.line(XES['Energy']+xoffset*0,XES['O_XES']+yoffset*4,line_color="orange",legend_label="0.60U_RKM6.23_600k_PU")

XES=xes60
p.line(XES['Energy']+xoffset*1,XES['O_XES']+yoffset*4,line_color="cyan",legend_label="0.60U_RKM7_300k_P4")

XES=xes70
p.line(XES['Energy']+xoffset*0,XES['O_XES']+yoffset*5,line_color="green",legend_label="0.70U_RKM7_300k_P4")

XES=xes70P3
p.line(XES['Energy']+xoffset*1,XES['O_XES']+yoffset*5,line_color="purple",legend_label="0.70U_RKM7_600k_P3")

p.legend.location = "top_left"
show(p)
# Out:
#   <div class="bk-root" id="3c910ad3-b0c2-4dcf-b8a7-22315ecc705e" data-root-id="3624"></div>

# %%
p = figure(title='CoFeMn Plus U Calculations', x_axis_label='Energy', y_axis_label='Counts',x_range=(460, 550))
yoffset = 0.05
xoffset = 20

XES=xas00
p.line(XES['Energy']+xoffset*0,XES['O_XAS']+yoffset*0,line_color="red",legend_label="0.00U_RKM7_300k_SP")

XES=xas30
p.line(XES['Energy']+xoffset*0,XES['O_XAS']+yoffset*1,line_color="blue",legend_label="0.30U_RKM6.23_600k_PU")

XES=xas50
p.line(XES['Energy']+xoffset*0,XES['O_XAS']+yoffset*2,line_color="magenta",legend_label="0.50U_RKM7_300k_P4")

XES=xas50P4
p.line(XES['Energy']+xoffset*1,XES['O_XAS']+yoffset*2,line_color="black",legend_label="0.50U_RKM7_600k_P4")

XES=xas52
p.line(XES['Energy']+xoffset*0,XES['O_XAS']+yoffset*3,line_color="brown",legend_label="0.52U_RKM6.23_600k_PU")

XES=xas60PU
p.line(XES['Energy']+xoffset*0,XES['O_XAS']+yoffset*4,line_color="orange",legend_label="0.60U_RKM6.23_600k_PU")

XES=xas60
p.line(XES['Energy']+xoffset*1,XES['O_XAS']+yoffset*4,line_color="cyan",legend_label="0.60U_RKM7_300k_P4")

XES=xas70
p.line(XES['Energy']+xoffset*0,XES['O_XAS']+yoffset*5,line_color="green",legend_label="0.70U_RKM7_300k_P4")

XES=xas70P3
p.line(XES['Energy']+xoffset*1,XES['O_XAS']+yoffset*5,line_color="purple",legend_label="0.70U_RKM7_300k_P3")

p.legend.location = "top_left"
show(p)
# Out:
#   <div class="bk-root" id="e0186f25-cc53-46e7-abea-c09d0a855d4c" data-root-id="2572"></div>

# %%
# Figure for group presentation
p = figure(title='CoFeMn Plus U Calculations SPIN DOWN', x_axis_label='Energy', y_axis_label='Counts',x_range=(490, 510))
yoffset = 0.03
xoffset = 20


XES=xes00
p.line(XES['Energy'],XES['O_XES']+yoffset*0,line_color="red",legend_label="0.00U_RKM7_300k_SP")

XES=xes30
p.line(XES['Energy']+0.55,XES['O_XES']+yoffset*1,line_color="blue",legend_label="0.30U_RKM6.23_600k_PU")
# x moved by 0.35 DN or 0.55
# 1.1 UP

#XES=xes50
#p.line(XES['Energy']+xoffset*0,XES['O_XES']+yoffset*2,line_color="magenta",legend_label="0.50U_RKM7_300k_P4")

#XES=xes50P4
#p.line(XES['Energy']+xoffset*1,XES['O_XES']+yoffset*2,line_color="black",legend_label="0.50U_RKM7_600k_P4")

XES=xes52
p.line(XES['Energy']+0.88,XES['O_XES']+yoffset*2,line_color="brown",legend_label="0.52U_RKM6.23_600k_PU")
# x moved by 0.68 DN Or 0.88
# 0.9 UP

XES=xes60PU
p.line(XES['Energy']+0.85,XES['O_XES']+yoffset*3,line_color="orange",legend_label="0.60U_RKM6.23_600k_PU")
# x moved by 0.28 DN or 0.85
# 1.15 UP

#XES=xes60
#p.line(XES['Energy']+xoffset*1,XES['O_XES']+yoffset*4,line_color="cyan",legend_label="0.60U_RKM7_300k_P4")

XES=xes70
p.line(XES['Energy']+0.95,XES['O_XES']+yoffset*4,line_color="green",legend_label="0.70U_RKM7_300k_P4")
# x moved by 0.28 DN or 0.95
# 1.3 UP

#XES=xes70P3
#p.line(XES['Energy']+xoffset*1,XES['O_XES']+yoffset*5,line_color="purple",legend_label="0.70U_RKM7_600k_P3")

p.legend.location = "top_left"
#span = Span(location=504.4, dimension='height', line_color='black', line_width=1)
#p.add_layout(span)
#span = Span(location=501.6, dimension='height', line_color='black', line_width=1)
#p.add_layout(span)
#span = Span(location=506.5, dimension='height', line_color='black', line_width=1)
#p.add_layout(span)
#span = Span(location=499.75, dimension='height', line_color='black', line_width=1)
#p.add_layout(span)

span = Span(location=502.1, dimension='height', line_color='black', line_width=1)
p.add_layout(span)
span = Span(location=506.2, dimension='height', line_color='black', line_width=1)
p.add_layout(span)
span = Span(location=500.75, dimension='height', line_color='black', line_width=1)
p.add_layout(span)
show(p)
# Out:
#   <div class="bk-root" id="feeabc86-dc86-4680-b7dc-d8ae541b79ea" data-root-id="195547"></div>

# %%
# Figure for group presentation
p = figure(title='CoFeMn Plus U Calculations', x_axis_label='Energy', y_axis_label='Counts',x_range=(490, 528))
yoffset = 0.01
xoffset = 20

XES=xas00
p.line(XES['Energy']+xoffset*0,XES['O_XAS']+yoffset*0,line_color="red",legend_label="0.00U_RKM7_300k_SP")

XES=xas30
p.line(XES['Energy']+0.55,XES['O_XAS']+yoffset*1,line_color="blue",legend_label="0.30U_RKM6.23_600k_PU")
# 1.1 SP UP

#XES=xas50
#p.line(XES['Energy']+xoffset*0,XES['O_XAS']+yoffset*2,line_color="magenta",legend_label="0.50U_RKM7_300k_P4")

#XES=xas50P4
#p.line(XES['Energy']+xoffset*1,XES['O_XAS']+yoffset*2,line_color="black",legend_label="0.50U_RKM7_600k_P4")

XES=xas52
p.line(XES['Energy']+0.88,XES['O_XAS']+yoffset*2,line_color="brown",legend_label="0.52U_RKM6.23_600k_PU")
# 0.9 SP UP

XES=xas60PU
p.line(XES['Energy']+0.85,XES['O_XAS']+yoffset*3,line_color="orange",legend_label="0.60U_RKM6.23_600k_PU")
# 1.15 SP UP

#XES=xas60
#p.line(XES['Energy']+xoffset*0,XES['O_XAS']+yoffset*3,line_color="cyan",legend_label="0.60U_RKM7_300k_P4")

XES=xas70
p.line(XES['Energy']+0.95,XES['O_XAS']+yoffset*4,line_color="green",legend_label="0.70U_RKM7_300k_P4")
# 1.3 SP UP

#XES=xas70P3
#p.line(XES['Energy']+xoffset*1,XES['O_XAS']+yoffset*5,line_color="purple",legend_label="0.70U_RKM7_300k_P3")

p.legend.location = "top_left"

span = Span(location=508.85, dimension='height', line_color='black', line_width=1) # SP DN
#span = Span(location=507.82, dimension='height', line_color='black', line_width=1) # SP UP
p.add_layout(span)
span = Span(location=518.8, dimension='height', line_color='black', line_width=1) # SP DN
#span = Span(location=518.34, dimension='height', line_color='black', line_width=1) # SP UP
p.add_layout(span)
show(p)
# Out:
#   <div class="bk-root" id="e7975268-20ef-4490-b2b1-ceea80c25259" data-root-id="198225"></div>

# %% [markdown]
# # Plotting all at 60U, but this time for different atoms

# %%
up_or_dn = "dn"
# 060U

# 000U, RKM7, 300k
xes00 = pd.read_csv('./CoFeMn/CoFeMn_000U_'+up_or_dn+'_O_XES.csv')
xas00 = pd.read_csv('./CoFeMn/CoFeMn_000U_'+up_or_dn+'_O_XAS.csv')

# RKM6.23, 600k, All Sites
xesAll = pd.read_csv('./CoFeMn/CoFeMn_060U_PU_'+up_or_dn+'_O_XES.csv')
xasAll = pd.read_csv('./CoFeMn/CoFeMn_060U_PU_'+up_or_dn+'_O_XAS.csv')

# RMK7, 300k, Only Co
xesCo = pd.read_csv('./CoFeMn/Only_Co_'+up_or_dn+'_O_XES.csv')
xasCo = pd.read_csv('./CoFeMn/Only_Co_'+up_or_dn+'_O_XAS.csv')

# RMK7, 300k, Only Fe
xesFe = pd.read_csv('./CoFeMn/Only_Fe_'+up_or_dn+'_O_XES.csv')
xasFe = pd.read_csv('./CoFeMn/Only_Fe_'+up_or_dn+'_O_XAS.csv')

# RMK7, 300k, Only Mn
xesMn = pd.read_csv('./CoFeMn/Only_Mn_'+up_or_dn+'_O_XES.csv')
xasMn = pd.read_csv('./CoFeMn/Only_Mn_'+up_or_dn+'_O_XAS.csv')

# RMK7, 300k, Only Site1
xesSite1 = pd.read_csv('./CoFeMn/Only_Site1_'+up_or_dn+'_O_XES.csv')
xasSite1 = pd.read_csv('./CoFeMn/Only_Site1_'+up_or_dn+'_O_XAS.csv')

# RMK7, 300k, Only Site2
xesSite2 = pd.read_csv('./CoFeMn/Only_Site2_'+up_or_dn+'_O_XES.csv')
xasSite2 = pd.read_csv('./CoFeMn/Only_Site2_'+up_or_dn+'_O_XAS.csv')

# %%
# XES Figures

p = figure(title='CoFeMn Plus U XES', x_axis_label='Energy',x_range=(490, 510))
yoffset = 0.03
xoffset = 20

XES=xes00
p.line(XES['Energy']-0.9,XES['O_XES']+yoffset*-1,line_color="green",legend_label="Ground State")

XES=xesAll
p.line(XES['Energy'],XES['O_XES']+yoffset*0,line_color="red",legend_label="All Sites")

XES=xesCo
p.line(XES['Energy']-0.5,XES['O_XES']+yoffset*1,line_color="blue",legend_label="Only Co")

XES=xesFe
p.line(XES['Energy']-0.5,XES['O_XES']+yoffset*2,line_color="brown",legend_label="Only Fe")

XES=xesMn
p.line(XES['Energy']-0.75,XES['O_XES']+yoffset*3,line_color="orange",legend_label="Only Mn")

XES=xesSite1
p.line(XES['Energy']-0.15,XES['O_XES']+yoffset*4,line_color="magenta",legend_label="Only Octahedral")

XES=xesSite2
p.line(XES['Energy']-0.5,XES['O_XES']+yoffset*5,line_color="black",legend_label="Only Tetrahedral")


p.legend.location = "top_left"
#span = Span(location=504.4, dimension='height', line_color='black', line_width=1)
#p.add_layout(span)
span = Span(location=501.2, dimension='height', line_color='black', line_width=1)
p.add_layout(span)
#span = Span(location=506.5, dimension='height', line_color='black', line_width=1)
#p.add_layout(span)
#span = Span(location=499.75, dimension='height', line_color='black', line_width=1)
#p.add_layout(span)

#span = Span(location=502.1, dimension='height', line_color='black', line_width=1)
#p.add_layout(span)
#span = Span(location=506.2, dimension='height', line_color='black', line_width=1)
#p.add_layout(span)
#span = Span(location=500.75, dimension='height', line_color='black', line_width=1)
#p.add_layout(span)
show(p)
# Out:
#   <div class="bk-root" id="b3c95aff-252b-4bfe-a336-af8a07dc6349" data-root-id="25336"></div>

# %%
# XAS Figures

p = figure(title='CoFeMn Plus U XAS', x_axis_label='Energy',x_range=(490, 528))
yoffset = 0.01
xoffset = 20

XES=xas00
p.line(XES['Energy']-0.9,XES['O_XAS']+yoffset*-1,line_color="green",legend_label="Ground State")
# -0.9 Dn
# 

XES=xasAll
p.line(XES['Energy']+xoffset*0,XES['O_XAS']+yoffset*0,line_color="red",legend_label="All Sites")

XES=xasCo
p.line(XES['Energy']-0.5,XES['O_XAS']+yoffset*1,line_color="blue",legend_label="Only Co")
# -0.5 Dn
# -0.7 Up

XES=xasFe
p.line(XES['Energy']-0.5,XES['O_XAS']+yoffset*2,line_color="brown",legend_label="Only Fe")
# -0.5 Dn
# -0.7 Up

XES=xasMn
p.line(XES['Energy']-0.75,XES['O_XAS']+yoffset*3,line_color="orange",legend_label="Only Mn")
# -0.75 Dn
# -0.95 Up

XES=xasSite1
p.line(XES['Energy']-0.15,XES['O_XAS']+yoffset*4,line_color="magenta",legend_label="Only Octahedral")
# -0.15 Dn
# -0.2 Up

XES=xasSite2
p.line(XES['Energy']-0.5,XES['O_XAS']+yoffset*5,line_color="black",legend_label="Only Tetrahedral")
# -0.5 Dn
# -0.75 Up


p.legend.location = "top_left"

span = Span(location=517.9, dimension='height', line_color='black', line_width=1) # SP DN
#span = Span(location=517.15, dimension='height', line_color='black', line_width=1) # SP UP
p.add_layout(span)
span = Span(location=507.9, dimension='height', line_color='black', line_width=1) # SP DN
#span = Span(location=506.2, dimension='height', line_color='black', line_width=1) # SP UP
p.add_layout(span)
show(p)
# Out:
#   <div class="bk-root" id="89e475de-f08e-4fd3-9c0e-4dcf0f45fdb4" data-root-id="23237"></div>
